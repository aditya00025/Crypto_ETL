# %%
import requests
import pandas as pd

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    'vs_currency': 'inr',
    'order': 'market_cap_desc',
    'per_page': 10,
    'page': 1,
    'sparkline': 'false'
}

# %%
response = requests.get(url, params=params)
data = response.json()

# %%
df = pd.json_normalize(data)
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3       ripple    xrp       XRP
# 4  binancecoin    bnb       BNB
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...     7283611.00
# 1  https://coin-images.coingecko.com/coins/images...      140122.00
# 2  https://coin-images.coingecko.com/coins/images...          85.96
# 3  https://coin-images.coingecko.com/coins/images...         186.94
# 4  https://coin-images.coingecko.com/coins/images...       50447.00
#
#         market_cap  market_cap_rank  fully_diluted_valuation   total_volume  \
# 0  144435640012095                1          144435800085349  2232087921575
# 1   16907265623364                2           16907265623364   938875969683
# 2   12411019219613                3           12411019219613  2595021676842
# 3   10895838679412                4           18674473561842   277387804944
# 4    7357550504788                5            7357550504788    38703890133
#
#      high_24h  ...  ath_change_percentage                  ath_date  \
# 0  7370623.00  ...              -22.71931  2025-01-20T09:11:54.494Z
# 1   142134.00  ...              -61.24462  2021-11-10T14:24:19.604Z
# 2       85.97  ...              -18.54226  2025-01-25T16:51:57.989Z
# 3      191.47  ...              -36.23776  2025-01-16T16:55:12.134Z
# 4    51472.00  ...              -24.50265  2024-12-04T10:35:25.220Z
#
#            atl  atl_change_percentage                  atl_date  roi  \
# 0  3993.420000           1.821029e+05  2013-07-05T00:00:00.000Z  NaN
# 1    28.130000           4.990804e+05  2015-10-20T00:00:00.000Z  NaN
# 2    36.860000           1.331908e+02  2015-03-02T00:00:00.000Z  NaN
# 3     0.159343           1.171816e+05  2013-08-16T00:00:00.000Z  NaN
# 4     2.580000           1.952532e+06  2017-10-19T00:00:00.000Z  NaN
#
#                last_updated  roi.times  roi.currency  roi.percentage
# 0  2025-04-13T18:39:24.457Z        NaN           NaN             NaN
# 1  2025-04-13T18:39:19.040Z  24.696873           btc     2469.687259
# 2  2025-04-13T18:39:18.472Z        NaN           NaN             NaN
# 3  2025-04-13T18:39:24.963Z        NaN           NaN             NaN
# 4  2025-04-13T18:39:23.538Z        NaN           NaN             NaN
#
# [5 rows x 29 columns]

# %%
print(df.columns.to_list())
# Out:
# ['id', 'symbol', 'name', 'image', 'current_price', 'market_cap', 'market_cap_rank', 'fully_diluted_valuation', 'total_volume', 'high_24h', 'low_24h', 'price_change_24h', 'price_change_percentage_24h', 'market_cap_change_24h', 'market_cap_change_percentage_24h', 'circulating_supply', 'total_supply', 'max_supply', 'ath', 'ath_change_percentage', 'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi', 'last_updated', 'roi.times', 'roi.currency', 'roi.percentage']

# %%
df = df[['id', 'symbol', 'name', 'current_price', 'market_cap', 'price_change_percentage_24h']]
df.columns = ['coin_id', 'symbol', 'name', 'price', 'market_cap', 'change_24h']

# %%
df.to_csv('crypto_prices.csv', index=False)

# %%
from google.colab import files
files.download("crypto_prices.csv")
